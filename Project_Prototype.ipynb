# %%
import pandas as pd
import seaborn as sns
instagram = pd.read_csv("instagram_global_top_1000.csv")
my_list = list(instagram)
instagram = instagram.drop(['Country', 'Scraped'], axis=1)
instagram.head()
# Out:
#    Rank        Account              Title  \
# 0     1      cristiano  Cristiano Ronaldo
# 1     2    kyliejenner            Kylie 🤍
# 2     3       leomessi          Leo Messi
# 3     4  kendalljenner            Kendall
# 4     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# 2  306300000.0        Argentina             4800000.0       6500000.0
# 3  217800000.0    United States             3400000.0       5400000.0
# 4  295800000.0    United States             2700000.0       3600000.0

# %%
grouped_category = instagram.groupby("Category")["Rank"].count().sort_values(ascending = False)
print(grouped_category)


category_list = grouped_category.index.tolist()
count_list = []
for element in category_list:
    count = element.count("|")
    count_list.append(count)
max_categories = max(count_list) + 1
# max number of genres an influencer has
print(max_categories)
    
print(category_list)
# Out:
# Category
# Music                                            170
# Cinema|Actors/actresses                          165
# Sports with a ball                               103
# Lifestyle                                         58
# Music|Cinema|Actors/actresses                     20
#                                                 ...
# Family|Finance|Economics                           1
# Family|Fashion|Modeling                            1
# Family|D|I|Y|Design                                1
# Extreme|Sports|Outdoor activity|Racing|Sports      1
# Sports with a ball|Shows                           1
# Name: Rank, Length: 165, dtype: int64
# 6
# ['Music', 'Cinema|Actors/actresses', 'Sports with a ball', 'Lifestyle', 'Music|Cinema|Actors/actresses', 'Modeling', 'Shows', 'Humor|Fun|Happiness', 'Beauty', 'Cinema|Actors/actresses|Lifestyle', 'Shows|Cinema|Actors/actresses', 'Music|Lifestyle', 'Music|Art|Artists', 'Fitness|Gym', 'Cinema|Actors/actresses|Modeling', 'Shows|Humor|Fun|Happiness', 'Adult content', 'Racing|Sports', 'Lifestyle|Beauty', 'Lifestyle|Modeling', 'Music|Fashion', 'Music|Cinema|Actors/actresses|Modeling', 'Music|Shows', 'Cinema|Actors/actresses|Music', 'Computers|Gadgets|Machinery|Technologies', 'Family', 'Music|Cinema|Actors/actresses|Lifestyle', 'Family|Lifestyle', 'Sports with a ball|Lifestyle', 'Modeling|Lifestyle', 'Modeling|Fashion', 'Lifestyle|Sports with a ball', 'Shows|Lifestyle', 'Computers|Gadgets', 'Lifestyle|Music', 'Fashion|Modeling', 'Music|Art|Artists|Cinema|Actors/actresses', 'Lifestyle|Art|Artists', 'Art|Artists', 'Lifestyle|Cinema|Actors/actresses', 'Business|Careers', 'Cars|Motorbikes', 'Music|Modeling', 'Fashion', 'Lifestyle|Shows', 'Literature|Journalism', 'Modeling|Lifestyle|Fashion', 'Luxury|Cars|Motorbikes', 'Music|Cinema|Actors/actresses|Fashion', 'Humor|Fun|Happiness|Cinema|Actors/actresses', 'Management|Marketing|Music', 'Modeling|Cinema|Actors/actresses', 'Finance|Economics|Business|Careers|Family', 'Food|Cooking', 'Music|Beauty', 'Music|Modeling|Art|Artists', 'Cinema|Actors/actresses|Modeling|Lifestyle', 'Beauty|Lifestyle', 'Art|Artists|Cinema|Actors/actresses', 'Clothing|Outfits|Lifestyle', 'Sports with a ball|Family', 'Cinema|Actors/actresses|Shows', 'Art|Artists|Fashion|Modeling', 'Cinema|Actors/actresses|Fitness|Gym', 'Photography', 'Shows|Modeling', 'Modeling|Beauty|Lifestyle', 'Shows|Cinema|Actors/actresses|Lifestyle', 'Shows|Cinema|Actors/actresses|Modeling', 'Modeling|Family', 'Shows|Family', 'Music|Fitness|Gym|Lifestyle', 'Shows|Fitness|Gym', 'Shows|Beauty|Family', 'Shows|Music', 'Machinery|Technologies|Computers|Gadgets', 'Literature|Journalism|Trainers|Coaches', 'Sports with a ball|Lifestyle|Kids|Toys', 'Sports with a ball|Literature|Journalism', 'Shows|Beauty|Lifestyle', 'Modeling|Lifestyle|Beauty', 'Modeling|Fashion|Lifestyle', 'Nature  landscapes|Science|Photography', 'Music|Family', 'Music|Clothing|Outfits', 'Literature|Journalism|Fashion', 'Music|Shows|Cinema|Actors/actresses', 'Nature  landscapes|Photography', 'Music|Beauty|Fashion', 'Nature  landscapes|Photography|Travel', 'Photography|Fashion', 'Shows|Adult content', 'Photography|Humor|Fun|Happiness', 'Photography|Lifestyle', 'Modeling|Music', 'Photography|Travel', 'Science|Machinery|Technologies', 'Science|Photography', 'Music|Kids|Toys', 'Literature|Journalism|Shows', 'Accessories|Jewellery|Clothing|Outfits|Fashion', 'Literature|Journalism|Cinema|Actors/actresses|Fashion', 'Lifestyle|Shows|Computers|Gadgets', 'Clothing|Outfits', 'Cinema|Actors/actresses|Photography', 'Cinema|Actors/actresses|Music|Shows', 'Cinema|Actors/actresses|Modeling|Clothing|Outfits', 'Cinema|Actors/actresses|Lifestyle|Fashion', 'Cinema|Actors/actresses|Humor|Fun|Happiness|Modeling', 'Cinema|Actors/actresses|Humor|Fun|Happiness', 'Cinema|Actors/actresses|Fashion', 'Cinema|Actors/actresses|Family', 'Cinema|Actors/actresses|Comics  sketches|Shows', 'Cinema|Actors/actresses|Comics  sketches', 'Cinema|Actors/actresses|Art|Artists', 'Cars|Motorbikes|Luxury|Racing|Sports', 'Cars|Motorbikes|Luxury', 'Business|Careers|Finance|Economics', 'Beauty|Modeling|Cinema|Actors/actresses', 'Beauty|Modeling|Adult content', 'Beauty|Family|Lifestyle', 'Beauty|Cinema|Actors/actresses|Modeling', 'Beauty|Cinema|Actors/actresses|Fashion', 'Beauty|Cinema|Actors/actresses', 'Beauty|Art|Artists|Modeling', 'Beauty|Art|Artists|Cinema|Actors/actresses', 'Art|Artists|Shows', 'Art|Artists|Fashion|Music', 'Art|Artists|Comics  sketches', 'Art|Artists|Cinema|Actors/actresses|Shows', 'Art|Artists|Beauty', 'Animals', 'Clothing|Outfits|Music', 'Clothing|Outfits|Shopping|Retail', 'Computers|Gadgets|Photography', 'Fitnes ...

# %%
#add columns that have each category

instagram_w_categories = instagram.rename(columns={"Category": "Category 1"})
instagram_w_categories["Category 2"] = "N/A"
instagram_w_categories["Category 3"] = "N/A"
instagram_w_categories["Category 4"] = "N/A"
instagram_w_categories["Category 5"] = "N/A"
instagram_w_categories["Category 6"] = "N/A"
instagram_w_categories.head()
# Out:
#    Rank        Account              Title  \
# 0     1      cristiano  Cristiano Ronaldo
# 1     2    kyliejenner            Kylie 🤍
# 2     3       leomessi          Leo Messi
# 3     4  kendalljenner            Kendall
# 4     5    selenagomez       Selena Gomez
#
#                                        Link                 Category 1  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg  \
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# 2  306300000.0        Argentina             4800000.0       6500000.0
# 3  217800000.0    United States             3400000.0       5400000.0
# 4  295800000.0    United States             2700000.0       3600000.0
#
#   Category 2 Category 3 Category 4 Category 5 Category 6
# 0        N/A        N/A        N/A        N/A        N/A
# 1        N/A        N/A        N/A        N/A        N/A
# 2        N/A        N/A        N/A        N/A        N/A
# 3        N/A        N/A        N/A        N/A        N/A
# 4        N/A        N/A        N/A        N/A        N/A

# %%
index = 0
for string in instagram_w_categories["Category 1"].astype(str):
    num = string.count("|")
    while num >= 0:
        category_list = string.split("|")
        instagram_w_categories.loc[index, ["Category " + str(num + 1)]] = category_list[num].strip()
        num -= 1
    index += 1

# %%
grouped_category_1 = instagram_w_categories.groupby("Category 1").size()
grouped_category_2 = instagram_w_categories.groupby("Category 2").size()
grouped_category_3 = instagram_w_categories.groupby("Category 3").size()
grouped_category_4 = instagram_w_categories.groupby("Category 4").size()
grouped_category_5 = instagram_w_categories.groupby("Category 5").size()
grouped_category_6 = instagram_w_categories.groupby("Category 6").size()

df_count = pd.concat([grouped_category_1, grouped_category_2, grouped_category_3, grouped_category_4, grouped_category_5, grouped_category_6], axis=1)
category_count = df_count.sum(axis=1)
update = category_count.drop(labels=['N/A', "I", "D", "Y", "nan"])
update = update.sort_values(ascending=False).astype(int)
update[:10]
# Out:
# Cinema                274
# Actors/actresses      274
# Music                 261
# Lifestyle             158
# Sports with a ball    117
# Modeling               80
# Shows                  68
# Beauty                 42
# Fashion                38
# Humor                  34
# dtype: int64

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: [Authentic engagement, Engagement avg, Followers, Rank]

# %%
display(instagram_w_categories)
# Out:
#      Rank        Account                           Title  \
# 0       1      cristiano               Cristiano Ronaldo
# 1       2    kyliejenner                         Kylie 🤍
# 2       3       leomessi                       Leo Messi
# 3       4  kendalljenner                         Kendall
# 4       5    selenagomez                    Selena Gomez
# ..    ...            ...                             ...
# 995   996  senoritasaeva                      Dina Saeva
# 996   997    manuelneuer                    Manuel Neuer
# 997   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998   999    mohanshakti                    Shakti Mohan
# 999  1000       eduincaz                       Eduin Caz
#
#                                          Link          Category 1  \
# 0        https://www.instagram.com/cristiano/  Sports with a ball
# 1      https://www.instagram.com/kyliejenner/             Fashion
# 2         https://www.instagram.com/leomessi/  Sports with a ball
# 3    https://www.instagram.com/kendalljenner/            Modeling
# 4      https://www.instagram.com/selenagomez/               Music
# ..                                        ...                 ...
# 995  https://www.instagram.com/senoritasaeva/           Lifestyle
# 996    https://www.instagram.com/manuelneuer/  Sports with a ball
# 997      https://www.instagram.com/sahilkhan/             Fitness
# 998    https://www.instagram.com/mohanshakti/                 Art
# 999       https://www.instagram.com/eduincaz/           Lifestyle
#
#        Followers Audience Country  Authentic engagement  Engagement avg  \
# 0    400100000.0            India             7800000.0       9500000.0
# 1    308800000.0    United States             6200000.0      10100000.0
# 2    306300000.0        Argentina             4800000.0       6500000.0
# 3    217800000.0    United States             3400000.0       5400000.0
# 4    295800000.0    United States             2700000.0       3600000.0
# ..           ...              ...                   ...             ...
# 995    7700000.0           Russia              246600.0        318200.0
# 996   11500000.0          Germany              146500.0        210200.0
# 997   10100000.0            India              176500.0        239800.0
# 998   13700000.0            India              146400.0        175500.0
# 999    6200000.0           Mexico              305600.0        391900.0
#
#     Category 2 Category 3        Category 4 Category 5 Category 6
# 0          N/A        N/A               N/A        N/A        N/A
# 1     Modeling     Beauty               N/A        N/A        N/A
# 2       Family        N/A               N/A        N/A        N/A
# 3      Fashion        N/A               N/A        N/A        N/A
# 4    Lifestyle        N/A               N/A        N/A        N/A
# ..         ...        ...               ...        ...        ...
# 995      Music   Modeling               N/A        N/A        N/A
# 996        N/A        N/A               N/A        N/A        N/A
# 997        Gym        N/A               N/A        N/A        N/A
# 998    Artists     Cinema  Actors/actresses        N/A        N/A
# 999        N/A        N/A               N/A        N/A        N/A
#
# [1000 rows x 14 columns]

# %%
country_cat_piv  = instagram_w_categories.groupby(["Audience Country","Category 1"])["Account"].count().unstack(fill_value=None).reset_index().rename_axis(None, axis=1)
display(country_cat_piv)
# Out:
#         Audience Country  Accessories  Adult content  Animals  Art  Beauty  \
# 0                Algeria          NaN            NaN      NaN  NaN     NaN
# 1              Argentina          NaN            NaN      NaN  NaN     NaN
# 2                 Brazil          NaN            1.0      NaN  2.0     5.0
# 3                  Chile          NaN            NaN      NaN  NaN     NaN
# 4                  China          NaN            NaN      NaN  NaN     NaN
# 5               Colombia          NaN            NaN      NaN  NaN     NaN
# 6                  Egypt          NaN            NaN      NaN  NaN     NaN
# 7                 France          NaN            NaN      NaN  NaN     1.0
# 8                Germany          NaN            NaN      NaN  NaN     NaN
# 9                  India          NaN            1.0      1.0  2.0     4.0
# 10             Indonesia          NaN            NaN      NaN  1.0     2.0
# 11                  Iran          NaN            NaN      NaN  NaN     NaN
# 12                  Iraq          NaN            NaN      NaN  NaN     NaN
# 13                 Italy          NaN            1.0      NaN  NaN     1.0
# 14                 Japan          NaN            NaN      NaN  NaN     NaN
# 15            Kazakhstan          NaN            NaN      NaN  NaN     NaN
# 16                Mexico          NaN            NaN      NaN  NaN     1.0
# 17               Morocco          NaN            NaN      NaN  NaN     NaN
# 18               Nigeria          NaN            NaN      NaN  NaN     NaN
# 19           Philippines          NaN            NaN      NaN  NaN     1.0
# 20                Poland          NaN            NaN      NaN  NaN     NaN
# 21                Russia          NaN            NaN      NaN  NaN     1.0
# 22          Saudi Arabia          NaN            NaN      NaN  NaN     NaN
# 23           South Korea          NaN            NaN      NaN  1.0     NaN
# 24                 Spain          NaN            NaN      NaN  NaN     NaN
# 25                 Syria          NaN            NaN      NaN  NaN     NaN
# 26              Thailand          NaN            NaN      NaN  NaN     NaN
# 27                Turkey          NaN            NaN      NaN  NaN     1.0
# 28  United Arab Emirates          NaN            NaN      NaN  NaN     NaN
# 29        United Kingdom          NaN            NaN      NaN  NaN     NaN
# 30         United States          1.0            4.0      NaN  6.0     9.0
#
#     Business  Cars  Cinema  Clothing  ...  Management  Modeling  Music  \
# 0        NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 1        NaN   NaN     NaN       NaN  ...         NaN       1.0   14.0
# 2        NaN   NaN    38.0       NaN  ...         1.0       9.0   39.0
# 3        NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 4        NaN   NaN     NaN       NaN  ...         NaN       NaN    1.0
# 5        NaN   NaN     1.0       NaN  ...         NaN       NaN    1.0
# 6        NaN   NaN     2.0       NaN  ...         NaN       NaN    2.0
# 7        NaN   NaN     NaN       NaN  ...         NaN       NaN    1.0
# 8        NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 9        2.0   1.0    66.0       NaN  ...         NaN       4.0   16.0
# 10       1.0   NaN    18.0       1.0  ...         1.0       6.0   43.0
# 11       NaN   2.0     5.0       NaN  ...         NaN       NaN    NaN
# 12       NaN   NaN     1.0       NaN  ...         NaN       NaN    1.0
# 13       NaN   NaN     1.0       NaN  ...         NaN       NaN    2.0
# 14       NaN   NaN     2.0       NaN  ...         NaN       NaN    NaN
# 15       NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 16       NaN   NaN     4.0       1.0  ...         NaN       1.0   19.0
# 17       NaN   NaN     1.0       NaN  ...         NaN       NaN    NaN
# 18       NaN   NaN     NaN       NaN  ...         NaN       NaN    4.0
# 19       NaN   NaN     2.0       NaN  ...         NaN       NaN    3.0
# 20       NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 21       1.0   NaN     3.0       NaN  ...         NaN       2.0    5.0
# 22       NaN   NaN     1.0       NaN  ...         NaN       1.0    NaN
# 23       NaN   NaN     2.0       NaN  ...         NaN       NaN    3.0
# 24       NaN   NaN     3.0       NaN  ...         NaN       NaN    4.0
# 25       NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 26       NaN   NaN     NaN       NaN  ...         NaN       1.0    3.0
# 27       NaN   NaN     9.0       NaN  ...         NaN       NaN    1.0
# 28       NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 29       NaN   NaN     NaN       NaN  ...         NaN       NaN    NaN
# 30       NaN   2.0    50.0       3.0  ...         NaN      12.0   81.0
#
#     Nature  landscapes  Photography  Racing  Science  Shows  \
# 0                  NaN          NaN     NaN      NaN    NaN
# 1                  NaN          NaN     NaN      NaN    1.0
# 2                  NaN          NaN     1.0      NaN    9.0
# 3                  NaN          NaN     NaN      NaN    NaN
# 4                  NaN          NaN     NaN      NaN    NaN
# 5                  NaN          NaN     NaN      NaN    3.0
# 6                  NaN          NaN     NaN      NaN    NaN
# 7                  NaN          NaN     NaN      NaN    NaN
# 8                  NaN          NaN     NaN      NaN    NaN
# 9                  NaN          1.0     NaN      1.0    4.0
# 10                 NaN          1.0     1.0      NaN    4.0
# 11                 NaN          NaN     NaN      NaN    1.0
# 12                 NaN          NaN     NaN      NaN    2.0
# 13                 NaN          NaN     2.0      NaN    NaN
# 14                 NaN          NaN     NaN      NaN    NaN
# 15                 NaN          NaN     NaN      NaN    1.0
# 16                 NaN          NaN     NaN      NaN    2.0
# 17                 NaN          NaN     NaN      NaN    NaN
# 18                 NaN          NaN     NaN      NaN    NaN
# 19                 NaN          NaN     NaN      NaN    NaN
# 20                 NaN          NaN     NaN      NaN    NaN
# 21                 NaN          1.0     NaN      NaN    7.0
# 22                 NaN          NaN     NaN      NaN    NaN
# 23                 NaN          2.0     NaN      NaN    NaN
# 24                 NaN          NaN     NaN      NaN    NaN
# 25                 NaN          NaN     NaN      NaN    NaN
# 26                 NaN          NaN     NaN      NaN    NaN
# 27                 NaN          NaN     NaN      NaN    NaN
# 28                 NaN          NaN     NaN      NaN    NaN
# 29                 NaN          NaN     NaN      NaN    NaN
# 30                 3.0          1.0     2.0      1.0   16.0
#
#     Sports with a ball   nan
# 0                  1.0   NaN
# 1                  5.0   2.0
# 2                 16.0  11.0
# 3                  1.0   NaN
# 4                  NaN   NaN
# 5                  1.0   NaN
# 6                  1.0   NaN
# 7                  3.0   NaN
# 8                  4.0   NaN
# 9                 13.0   5.0
# 10                 2.0  29.0
# 11                 3.0   5.0
# 12                 NaN   NaN
# 13                 4.0   2.0
# 14                 NaN   NaN
# 15                 NaN   1.0
# 16                 NaN  10.0
# 17                 2.0   NaN
# 18                 NaN   NaN
# 19                 NaN   NaN
# 20                 1.0   NaN
# 21                 NaN   1.0
# 22                 NaN   NaN
# 23                 NaN   3.0
# 24                25.0   1.0
# 25                 NaN   NaN
# 26                 NaN   NaN
# 27                 2.0   NaN
# 28                 NaN   NaN
# 29                13.0   NaN
# 30                15.0  17.0
#
# [31 rows x 33 columns]

# %%
import matplotlib.pyplot as plt
country_cat_piv.plot(kind='bar', x="Audience Country", stacked=True)
plt.xlabel("Audience Country")
plt.ylabel("Count")
plt.title("Category Counts by Audience Country") 
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper right', borderaxespad=0)

# %%
country_cat_piv = country_cat_piv.set_index("Audience Country")
country_cat_piv['Max Category'] = country_cat_piv.idxmax(axis="columns")
display(country_cat_piv)
country_cat_piv = country_cat_piv.reset_index(drop=True)
display(country_cat_piv)

#country_pop_cat = country_cat_piv[['Audience Country', 'Max Category']]
#country_pop_cat
# Out:
#                       Accessories  Adult content  Animals  Art  Beauty  \
# Audience Country
# Algeria                       NaN            NaN      NaN  NaN     NaN
# Argentina                     NaN            NaN      NaN  NaN     NaN
# Brazil                        NaN            1.0      NaN  2.0     5.0
# Chile                         NaN            NaN      NaN  NaN     NaN
# China                         NaN            NaN      NaN  NaN     NaN
# Colombia                      NaN            NaN      NaN  NaN     NaN
# Egypt                         NaN            NaN      NaN  NaN     NaN
# France                        NaN            NaN      NaN  NaN     1.0
# Germany                       NaN            NaN      NaN  NaN     NaN
# India                         NaN            1.0      1.0  2.0     4.0
# Indonesia                     NaN            NaN      NaN  1.0     2.0
# Iran                          NaN            NaN      NaN  NaN     NaN
# Iraq                          NaN            NaN      NaN  NaN     NaN
# Italy                         NaN            1.0      NaN  NaN     1.0
# Japan                         NaN            NaN      NaN  NaN     NaN
# Kazakhstan                    NaN            NaN      NaN  NaN     NaN
# Mexico                        NaN            NaN      NaN  NaN     1.0
# Morocco                       NaN            NaN      NaN  NaN     NaN
# Nigeria                       NaN            NaN      NaN  NaN     NaN
# Philippines                   NaN            NaN      NaN  NaN     1.0
# Poland                        NaN            NaN      NaN  NaN     NaN
# Russia                        NaN            NaN      NaN  NaN     1.0
# Saudi Arabia                  NaN            NaN      NaN  NaN     NaN
# South Korea                   NaN            NaN      NaN  1.0     NaN
# Spain                         NaN            NaN      NaN  NaN     NaN
# Syria                         NaN            NaN      NaN  NaN     NaN
# Thailand                      NaN            NaN      NaN  NaN     NaN
# Turkey                        NaN            NaN      NaN  NaN     1.0
# United Arab Emirates          NaN            NaN      NaN  NaN     NaN
# United Kingdom                NaN            NaN      NaN  NaN     NaN
# United States                 1.0            4.0      NaN  6.0     9.0
#
#                       Business  Cars  Cinema  Clothing  Computers  ...  \
# Audience Country                                                   ...
# Algeria                    NaN   NaN     NaN       NaN        NaN  ...
# Argentina                  NaN   NaN     NaN       NaN        NaN  ...
# Brazil                     NaN   NaN    38.0       NaN        1.0  ...
# Chile                      NaN   NaN     NaN       NaN        NaN  ...
# China                      NaN   NaN     NaN       NaN        NaN  ...
# Colombia                   NaN   NaN     1.0       NaN        NaN  ...
# Egypt                      NaN   NaN     2.0       NaN        NaN  ...
# France                     NaN   NaN     NaN       NaN        NaN  ...
# Germany                    NaN   NaN     NaN       NaN        NaN  ...
# India                      2.0   1.0    66.0       NaN        2.0  ...
# Indonesia                  1.0   NaN    18.0       1.0        NaN  ...
# Iran                       NaN   2.0     5.0       NaN        NaN  ...
# Iraq                       NaN   NaN     1.0       NaN        NaN  ...
# Italy                      NaN   NaN     1.0       NaN        NaN  ...
# Japan                      NaN   NaN     2.0       NaN        NaN  ...
# Kazakhstan                 NaN   NaN     NaN       NaN        NaN  ...
# Mexico                     NaN   NaN     4.0       1.0        1.0  ...
# Morocco                    NaN   NaN     1.0       NaN        NaN  ...
# Nigeria                    NaN   NaN     NaN       NaN        NaN  ...
# Philippines                NaN   NaN     2.0       NaN        NaN  ...
# Poland                     NaN   NaN     NaN       NaN        NaN  ...
# Russia                     1.0   NaN     3.0       NaN        NaN  ...
# Saudi Arabia               NaN   NaN     1.0       NaN        NaN  ...
# South Korea                NaN   NaN     2.0       NaN        NaN  ...
# Spain                      NaN   NaN     3.0       NaN        1.0  ...
# Syria                      NaN   NaN     NaN       NaN        NaN  ...
# Thailand                   NaN   NaN     NaN       NaN        NaN  ...
# Turkey                     NaN   NaN     9.0       NaN        NaN  ...
# United Arab Emirates       NaN   NaN     NaN       NaN        NaN  ...
# United Kingdom             NaN   NaN     NaN       NaN        NaN  ...
# United States              NaN   2.0    50.0       3.0        3.0  ...
#
#                       Modeling  Music  Nature  landscapes  Photography  \
# Audience Country
# Algeria                    NaN    NaN                 NaN          NaN
# Argentina                  1.0   14.0                 NaN          NaN
# Brazil                     9.0   39.0                 NaN          NaN
# Chile                      NaN    NaN                 NaN          NaN
# China                      NaN    1.0                 NaN          NaN
# Colombia                   NaN    1.0                 NaN          NaN
# Egypt                      NaN    2.0                 NaN          NaN
# France                     NaN    1.0                 NaN          NaN
# Germany                    NaN    NaN                 NaN          NaN
# India                      4.0   16.0                 NaN          1.0
# Indonesia                  6.0   43.0                 NaN          1.0
# Iran                       NaN    NaN                 NaN          NaN
# Iraq                       NaN    1.0                 NaN          NaN
# Italy                      NaN    2.0                 NaN          NaN
# Japan                      NaN    NaN                 NaN          NaN
# Kazakhstan                 NaN    NaN                 NaN          NaN
# Mexico                     1.0   19.0                 NaN          NaN
# Morocco                    NaN    NaN                 NaN          NaN
# Nigeria                    NaN    4.0                 NaN          NaN
# Philippines                NaN    3.0                 NaN          NaN
# Poland                     NaN    NaN                 NaN          NaN
# Russia                     2.0    5.0                 NaN          1.0
# Saudi Arabia               1.0    NaN                 NaN          NaN
# South Korea                NaN    3.0                 NaN          2.0
# Spain                      NaN    4.0                 NaN          NaN
# Syria                      NaN    NaN                 NaN          NaN
# Thailand                   1.0    3.0                 NaN          NaN
# Turkey                     NaN    1.0                 NaN          NaN
# United Arab Emirates       NaN    NaN                 NaN          NaN
# United Kingdom             NaN    NaN                 NaN          NaN
# United States             12.0   81.0                 3.0          1.0
#
#                       Racing  Science  Shows  Sports with a ball   nan  \
# Audience Country
# Algeria                  NaN      NaN    NaN                 1.0   NaN
# Argentina                NaN      NaN    1.0                 5.0   2.0
# Brazil                   1.0      NaN    9.0                16.0  11.0
# Chile                    NaN      NaN    NaN                 1.0   NaN
# China                    NaN      NaN    NaN                 NaN   NaN
# Colombia                 NaN      NaN    3.0                 1.0   NaN
# Egypt                    NaN      NaN    NaN                 1.0   NaN
# France                   NaN      NaN    NaN                 3.0   NaN
# Germany                  NaN      NaN    NaN                 4.0   NaN
# India                    NaN      1.0    4.0                13.0   5.0
# Indonesia                1.0      NaN    4.0                 2.0  29.0
# Iran                     NaN      NaN    1.0                 3.0   5.0
# Iraq                     NaN      NaN    2.0                 NaN   NaN
# Italy                    2.0      NaN    NaN                 4.0   2.0
# Japan                    NaN      NaN    NaN                 NaN   NaN
# Kazakhstan               NaN      NaN    1.0                 NaN   1.0
# Mexico                   NaN      NaN    2.0                 NaN  10.0
# Morocco                  NaN      NaN    NaN                 2.0   NaN
# Nigeria                  NaN      NaN    NaN                 NaN   NaN
# Philippines              NaN      NaN    NaN                 NaN   NaN
# Poland                   NaN      NaN    NaN                 1.0   NaN
# Russia                   NaN      NaN    7.0                 NaN   1.0
# Saudi Arabia             NaN      NaN    NaN                 NaN   NaN
# South Korea              NaN      NaN    NaN                 NaN   3.0
# Spain                    NaN      NaN    NaN                25.0   1.0
# Syria                    NaN      NaN    NaN                 NaN   NaN
# Thailand                 NaN      NaN    NaN                 NaN   NaN
# Turkey                   NaN      NaN    NaN                 2.0   NaN
# United Arab Emirates     NaN      NaN    NaN                 NaN   NaN
# United Kingdom           NaN      NaN    NaN                13.0   NaN
# United States            2.0      1.0   16.0                15.0  17.0
#
#                             Max Category
# Audience Country
# Algeria               Sports with a ball
# Argentina                          Music
# Brazil                             Music
# Chile                 Sports with a ball
# China                              Music
# Colombia                       Lifestyle
# Egypt                             Cinema
# France                Sports with a ball
# Germany               Sports with a ball
# India                             Cinema
# Indonesia                          Music
# Iran                              Cinema
# Iraq                               Shows
# Italy                 Sports with a ball
# Japan                             Cinema
# Kazakhstan                         Shows
# Mexico                             Music
# Morocco               Sports with a ball
# Nigeria                            Music
# Philippines                        Music
# Poland                Sports with a ball
# Russia                             Shows
# Saudi Arabia                      Cinema
# South Korea                        Music
# Spain                 Sports with a ball
# Syria                          Lifestyle
# Thailand                           Music
# Turkey                            Cinema
# United Arab Emirates           Lifestyle
# United Kingdom        Sports with a ball
# United States                      Music
#
# [31 rows x 33 columns]
#     Accessories  Adult content  Animals  Art  Beauty  Business  Cars  Cinema  \
# 0           NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 1           NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 2           NaN            1.0      NaN  2.0     5.0       NaN   NaN    38.0
# 3           NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 4           NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 5           NaN            NaN      NaN  NaN     NaN       NaN   NaN     1.0
# 6           NaN            NaN      NaN  NaN     NaN       NaN   NaN     2.0
# 7           NaN            NaN      NaN  NaN     1.0       NaN   NaN     NaN
# 8           NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 9           NaN            1.0      1.0  2.0     4.0       2.0   1.0    66.0
# 10          NaN            NaN      NaN  1.0     2.0       1.0   NaN    18.0
# 11          NaN            NaN      NaN  NaN     NaN       NaN   2.0     5.0
# 12          NaN            NaN      NaN  NaN     NaN       NaN   NaN     1.0
# 13          NaN            1.0      NaN  NaN     1.0       NaN   NaN     1.0
# 14          NaN            NaN      NaN  NaN     NaN       NaN   NaN     2.0
# 15          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 16          NaN            NaN      NaN  NaN     1.0       NaN   NaN     4.0
# 17          NaN            NaN      NaN  NaN     NaN       NaN   NaN     1.0
# 18          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 19          NaN            NaN      NaN  NaN     1.0       NaN   NaN     2.0
# 20          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 21          NaN            NaN      NaN  NaN     1.0       1.0   NaN     3.0
# 22          NaN            NaN      NaN  NaN     NaN       NaN   NaN     1.0
# 23          NaN            NaN      NaN  1.0     NaN       NaN   NaN     2.0
# 24          NaN            NaN      NaN  NaN     NaN       NaN   NaN     3.0
# 25          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 26          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 27          NaN            NaN      NaN  NaN     1.0       NaN   NaN     9.0
# 28          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 29          NaN            NaN      NaN  NaN     NaN       NaN   NaN     NaN
# 30          1.0            4.0      NaN  6.0     9.0       NaN   2.0    50.0
#
#     Clothing  Computers  ...  Modeling  Music  Nature  landscapes  \
# 0        NaN        NaN  ...       NaN    NaN                 NaN
# 1        NaN        NaN  ...       1.0   14.0                 NaN
# 2        NaN        1.0  ...       9.0   39.0                 NaN
# 3        NaN        NaN  ...       NaN    NaN                 NaN
# 4        NaN        NaN  ...       NaN    1.0                 NaN
# 5        NaN        NaN  ...       NaN    1.0                 NaN
# 6        NaN        NaN  ...       NaN    2.0                 NaN
# 7        NaN        NaN  ...       NaN    1.0                 NaN
# 8        NaN        NaN  ...       NaN    NaN                 NaN
# 9        NaN        2.0  ...       4.0   16.0                 NaN
# 10       1.0        NaN  ...       6.0   43.0                 NaN
# 11       NaN        NaN  ...       NaN    NaN                 NaN
# 12       NaN        NaN  ...       NaN    1.0                 NaN
# 13       NaN        NaN  ...       NaN    2.0                 NaN
# 14       NaN        NaN  ...       NaN    NaN                 NaN
# 15       NaN        NaN  ...       NaN    NaN                 NaN
# 16       1.0        1.0  ...       1.0   19.0                 NaN
# 17       NaN        NaN  ...       NaN    NaN                 NaN
# 18       NaN        NaN  ...       NaN    4.0                 NaN
# 19       NaN        NaN  ...       NaN    3.0                 NaN
# 20       NaN        NaN  ...       NaN    NaN                 NaN
# 21       NaN        NaN  ...       2.0    5.0                 NaN
# 22       NaN        NaN  ...       1.0    NaN                 NaN
# 23       NaN        NaN  ...       NaN    3.0                 NaN
# 24       NaN        1.0  ...       NaN    4.0                 NaN
# 25       NaN        NaN  ...       NaN    NaN                 NaN
# 26       NaN        NaN  ...       1.0    3.0                 NaN
# 27       NaN        NaN  ...       NaN    1.0                 NaN
# 28       NaN        NaN  ...       NaN    NaN                 NaN
# 29       NaN        NaN  ...       NaN    NaN                 NaN
# 30       3.0        3.0  ...      12.0   81.0                 3.0
#
#     Photography  Racing  Science  Shows  Sports with a ball   nan  \
# 0           NaN     NaN      NaN    NaN                 1.0   NaN
# 1           NaN     NaN      NaN    1.0                 5.0   2.0
# 2           NaN     1.0      NaN    9.0                16.0  11.0
# 3           NaN     NaN      NaN    NaN                 1.0   NaN
# 4           NaN     NaN      NaN    NaN                 NaN   NaN
# 5           NaN     NaN      NaN    3.0                 1.0   NaN
# 6           NaN     NaN      NaN    NaN                 1.0   NaN
# 7           NaN     NaN      NaN    NaN                 3.0   NaN
# 8           NaN     NaN      NaN    NaN                 4.0   NaN
# 9           1.0     NaN      1.0    4.0                13.0   5.0
# 10          1.0     1.0      NaN    4.0                 2.0  29.0
# 11          NaN     NaN      NaN    1.0                 3.0   5.0
# 12          NaN     NaN      NaN    2.0                 NaN   NaN
# 13          NaN     2.0      NaN    NaN                 4.0   2.0
# 14          NaN     NaN      NaN    NaN                 NaN   NaN
# 15          NaN     NaN      NaN    1.0                 NaN   1.0
# 16          NaN     NaN      NaN    2.0                 NaN  10.0
# 17          NaN     NaN      NaN    NaN                 2.0   NaN
# 18          NaN     NaN      NaN    NaN                 NaN   NaN
# 19          NaN     NaN      NaN    NaN                 NaN   NaN
# 20          NaN     NaN      NaN    NaN                 1.0   NaN
# 21          1.0     NaN      NaN    7.0                 NaN   1.0
# 22          NaN     NaN      NaN    NaN                 NaN   NaN
# 23          2.0     NaN      NaN    NaN                 NaN   3.0
# 24          NaN     NaN      NaN    NaN                25.0   1.0
# 25          NaN     NaN      NaN    NaN                 NaN   NaN
# 26          NaN     NaN      NaN    NaN                 NaN   NaN
# 27          NaN     NaN      NaN    NaN                 2.0   NaN
# 28          NaN     NaN      NaN    NaN                 NaN   NaN
# 29          NaN     NaN      NaN    NaN                13.0   NaN
# 30          1.0     2.0      1.0   16.0                15.0  17.0
#
#           Max Category
# 0   Sports with a ball
# 1                Music
# 2                Music
# 3   Sports with a ball
# 4                Music
# 5            Lifestyle
# 6               Cinema
# 7   Sports with a ball
# 8   Sports with a ball
# 9               Cinema
# 10               Music
# 11              Cinema
# 12               Shows
# 13  Sports with a ball
# 14              Cinema
# 15               Shows
# 16               Music
# 17  Sports with a ball
# 18               Music
# 19               Music
# 20  Sports with a ball
# 21               Shows
# 22              Cinema
# 23               Music
# 24  Sports with a ball
# 25           Lifestyle
# 26               Music
# 27              Cinema
# 28           Lifestyle
# 29  Sports with a ball
# 30               Music
#
# [31 rows x 33 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()

# %%
sns.displot(data=instagram_w_categories, x="Authentic engagement", y="Engagement avg", cbar=True)

# %%
sns.relplot(x="Authentic engagement",y="Engagement avg", hue = "Category 1", data=instagram_w_categories)

# %%
mask = instagram_w_categories[(instagram_w_categories["Category 1"]=='Music')|(instagram_w_categories["Category 1"]=='Cinema')|(instagram_w_categories["Category 1"]=='Actor/actresses')|(instagram_w_categories["Category 1"]=='Sports with a ball')|(instagram_w_categories["Category 1"]=='Lifestyle')]

sns.relplot(x="Authentic engagement",y="Engagement avg", hue = "Category 1", data=mask)

# %%
sns.relplot(x='Authentic engagement',y='Engagement avg', col= "Category 1", hue = 'Category 1', height =3,estimator = None, kind = 'line', data = mask)

# %%
less = mask[(mask["Authentic engagement"]< 4000000)&(mask["Engagement avg"]< 4000000)]
sns.relplot(x='Authentic engagement',y='Engagement avg', col= "Category 1", hue = 'Category 1', height =3,estimator = None, kind = 'line', data = less)

# %%
sns.relplot(x='Authentic engagement',y='Followers', col= "Category 1", hue = 'Category 1', height =3,estimator = None, data = less)

# %%
sns.displot(data=less, x="Authentic engagement", y="Engagement avg", cbar=True)
