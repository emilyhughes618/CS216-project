# %%
import pandas as pd
instagram = pd.read_csv("instagram_global_top_1000.csv")
my_list = list(instagram)
instagram = instagram.drop(['Country', 'Scraped'], axis=1)
instagram.head()
# Out:
#    Rank        Account              Title  \
# 0     1      cristiano  Cristiano Ronaldo
# 1     2    kyliejenner            Kylie 🤍
# 2     3       leomessi          Leo Messi
# 3     4  kendalljenner            Kendall
# 4     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#      Followers Audience Country  Authentic engagement  Engagement avg
# 0  400100000.0            India             7800000.0       9500000.0
# 1  308800000.0    United States             6200000.0      10100000.0
# 2  306300000.0        Argentina             4800000.0       6500000.0
# 3  217800000.0    United States             3400000.0       5400000.0
# 4  295800000.0    United States             2700000.0       3600000.0

# %%
grouped_category = instagram.groupby("Category")["Rank"].count()
category_list = grouped_category.index.tolist()
count_list = []
for element in category_list:
    count = element.count("|")
    count_list.append(count)
max_categories = max(count_list) + 1
# max number of genres an influencer has
print(max_categories)
    
print(category_list)
# Out:
# 6
# ['Accessories|Jewellery|Clothing|Outfits|Fashion', 'Adult content', 'Animals', 'Art|Artists', 'Art|Artists|Beauty', 'Art|Artists|Cinema|Actors/actresses', 'Art|Artists|Cinema|Actors/actresses|Shows', 'Art|Artists|Comics  sketches', 'Art|Artists|Fashion|Modeling', 'Art|Artists|Fashion|Music', 'Art|Artists|Shows', 'Beauty', 'Beauty|Art|Artists|Cinema|Actors/actresses', 'Beauty|Art|Artists|Modeling', 'Beauty|Cinema|Actors/actresses', 'Beauty|Cinema|Actors/actresses|Fashion', 'Beauty|Cinema|Actors/actresses|Modeling', 'Beauty|Family|Lifestyle', 'Beauty|Lifestyle', 'Beauty|Modeling|Adult content', 'Beauty|Modeling|Cinema|Actors/actresses', 'Business|Careers', 'Business|Careers|Finance|Economics', 'Cars|Motorbikes', 'Cars|Motorbikes|Luxury', 'Cars|Motorbikes|Luxury|Racing|Sports', 'Cinema|Actors/actresses', 'Cinema|Actors/actresses|Art|Artists', 'Cinema|Actors/actresses|Comics  sketches', 'Cinema|Actors/actresses|Comics  sketches|Shows', 'Cinema|Actors/actresses|Family', 'Cinema|Actors/actresses|Fashion', 'Cinema|Actors/actresses|Fitness|Gym', 'Cinema|Actors/actresses|Humor|Fun|Happiness', 'Cinema|Actors/actresses|Humor|Fun|Happiness|Modeling', 'Cinema|Actors/actresses|Lifestyle', 'Cinema|Actors/actresses|Lifestyle|Fashion', 'Cinema|Actors/actresses|Modeling', 'Cinema|Actors/actresses|Modeling|Clothing|Outfits', 'Cinema|Actors/actresses|Modeling|Lifestyle', 'Cinema|Actors/actresses|Music', 'Cinema|Actors/actresses|Music|Shows', 'Cinema|Actors/actresses|Photography', 'Cinema|Actors/actresses|Shows', 'Clothing|Outfits', 'Clothing|Outfits|Lifestyle', 'Clothing|Outfits|Music', 'Clothing|Outfits|Shopping|Retail', 'Computers|Gadgets', 'Computers|Gadgets|Machinery|Technologies', 'Computers|Gadgets|Photography', 'Extreme|Sports|Outdoor activity', 'Extreme|Sports|Outdoor activity|Racing|Sports', 'Family', 'Family|D|I|Y|Design', 'Family|Fashion|Modeling', 'Family|Finance|Economics', 'Family|Lifestyle', 'Family|Lifestyle|Shows', 'Family|Music', 'Family|Sports with a ball', 'Fashion', 'Fashion|Beauty', 'Fashion|Cinema|Actors/actresses', 'Fashion|Clothing|Outfits|Accessories|Jewellery', 'Fashion|Lifestyle|Beauty', 'Fashion|Modeling', 'Fashion|Modeling|Beauty', 'Finance|Economics', 'Finance|Economics|Business|Careers', 'Finance|Economics|Business|Careers|Family', 'Fitness|Gym', 'Fitness|Gym|Lifestyle', 'Fitness|Gym|Shopping|Retail|Clothing|Outfits', 'Food|Cooking', 'Humor|Fun|Happiness', 'Humor|Fun|Happiness|Cinema|Actors/actresses', 'Humor|Fun|Happiness|Clothing|Outfits', 'Humor|Fun|Happiness|Lifestyle', 'Humor|Fun|Happiness|Shows|Art|Artists', 'Kids|Toys|Family', 'Lifestyle', 'Lifestyle|Art|Artists', 'Lifestyle|Beauty', 'Lifestyle|Business|Careers', 'Lifestyle|Cinema|Actors/actresses', 'Lifestyle|Cinema|Actors/actresses|Music', 'Lifestyle|Clothing|Outfits', 'Lifestyle|Fashion', 'Lifestyle|Fashion|Clothing|Outfits', 'Lifestyle|Modeling', 'Lifestyle|Modeling|Cinema|Actors/actresses', 'Lifestyle|Modeling|Fashion', 'Lifestyle|Music', 'Lifestyle|Music|Modeling', 'Lifestyle|Shows', 'Lifestyle|Shows|Computers|Gadgets', 'Lifestyle|Sports with a ball', 'Literature|Journalism', 'Literature|Journalism|Cinema|Actors/actresses|Fashion', 'Literature|Journalism|Fashion', 'Literature|Journalism|Shows', 'Literature|Journalism|Trainers|Coaches', 'Luxury|Cars|Motorbikes', 'Machinery|Technologies|Computers|Gadgets', 'Management|Marketing|Music', 'Modeling', 'Modeling|Beauty|Lifestyle', 'Modeling|Cinema|Actors/actresses', 'Modeling|Family', 'Modeling|Fashion', 'Modeling|Fashion|Lifestyle', 'Modeling|Lifestyle', 'Modeling|Lifestyle|Beauty', 'Modeling|Lifestyle|Fashion', 'Modeling|Music', 'Music', 'Music|Art|Artists', 'Music|Art|Artists|Cinema|Actors/actresses', 'Music|Beauty', 'Music|Beauty|Fashion', 'Music|Cinema|Actors/actresses', 'Music|Cinema|Actors/actresses|Fashion', 'Music|Cinema|Actors/actresses|Lifestyle', 'Music|Cinema|Actors/actresses|Modeling', 'Music|Clothing|Outfits', 'Music|Family', 'Music|Fashion', 'Music|Fitness|Gym|Lifestyle', 'Music|Kids|Toys', 'M ...
